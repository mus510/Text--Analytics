# %%
# For text preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# For topic modeling
from gensim import corpora
from gensim.models import LdaModel

# Download NLTK Resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/636644db-8fc4-4270-b0b1-d34d5059807c/nltk_data..
# [nltk_data]     .
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/636644db-8fc4-4270-b0b1-d34d5059807c/nltk_data..
# [nltk_data]     .
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/636644db-8fc4-4270-b0b1-d34d5059807c/nltk_data..
# [nltk_data]     .
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
documents = [
    "Rafael Nadal Joins Roger Federer in Missing U.S. Open",
    "Rafael Nadal Is Out of the Australian Open",
    "Biden Announces Virus Measures",
    "Biden's Virus Plans Meet Reality",
    "Where Biden's Virus Plan Stands"
]

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalnum()]
    tokens = [token for token in tokens if token not in stop_words]
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

preprocessed_documents = [preprocess_text(doc) for doc in documents]

print(preprocessed_documents)
# Out:
# [['rafael', 'nadal', 'join', 'roger', 'federer', 'missing', 'open'], ['rafael', 'nadal', 'australian', 'open'], ['biden', 'announces', 'virus', 'measure'], ['biden', 'virus', 'plan', 'meet', 'reality'], ['biden', 'virus', 'plan', 'stand']]

# %%
dictionary = corpora.Dictionary(preprocessed_documents)
corpus = [dictionary.doc2bow(doc) for doc in preprocessed_documents]

# %%
lda_model = LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)

# %%
article_labels = []

for i, doc in enumerate(preprocessed_documents):
    bow = dictionary.doc2bow(doc)
    topics = lda_model.get_document_topics(bow)
    dominant_topic = max(topics, key=lambda x: x[1])[0]
    article_labels.append(dominant_topic)

# Print result
for i in range(len(documents)):
    print(f"{documents[i]} ---> Topic {article_labels[i]}")
# Out:
# Rafael Nadal Joins Roger Federer in Missing U.S. Open ---> Topic 0
# Rafael Nadal Is Out of the Australian Open ---> Topic 0
# Biden Announces Virus Measures ---> Topic 1
# Biden's Virus Plans Meet Reality ---> Topic 1
# Where Biden's Virus Plan Stands ---> Topic 1

# %%
print("Top Terms for Each Topic:")
for idx, topic in lda_model.print_topics():
    print(f"Topic {idx}: {topic}")
# Out:
# Top Terms for Each Topic:
# Topic 0: 0.131*"open" + 0.131*"rafael" + 0.131*"nadal" + 0.079*"roger" + 0.079*"missing" + 0.079*"federer" + 0.079*"join" + 0.079*"australian" + 0.027*"virus" + 0.027*"biden"
# Topic 1: 0.166*"biden" + 0.166*"virus" + 0.119*"plan" + 0.071*"meet" + 0.071*"reality" + 0.071*"stand" + 0.071*"measure" + 0.071*"announces" + 0.024*"australian" + 0.024*"nadal"
